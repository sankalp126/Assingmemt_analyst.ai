# %%
# !pip install requests
# !pip install html5lib
# !pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests) (2022.12.7)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: html5lib in /usr/local/lib/python3.8/dist-packages (1.0.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.8/dist-packages (from html5lib) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bs4 in /usr/local/lib/python3.8/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from bs4) (4.6.3)

# %%
import pandas as pd
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://www.amazon.in/s?k=bags&crid=2M096C61O4MLT&qid=1653308124&sprefix=ba%2Caps%2C283&ref=sr_pg_1"

# %%
r=requests.get(url,headers={"User-Agent": "YZ"})

# %%
soup=BeautifulSoup(r.content,'html.parser')

# %%
print(soup.prettify())

# %%
div_data=soup.find_all("div",attrs={"class":"sg-col sg-col-4-of-12 sg-col-8-of-16 sg-col-12-of-20 s-list-col-right"})

# %%
len(div_data)
# Out:
# 22

# %%
print((div_data)[0].prettify())

# %%
# <span class="a-size-medium a-color-base a-text-normal">
#        URBAN TRIBE Havana 15.6" inch Laptop Backpack for Men and Women | 27L Office/Work/Casual Bag | Water Repellent | Black
#       </span>
#     <span class="a-offscreen">₹998 </span>
#     <span class="a-icon-alt">3.9 out of 5 stars</span>
#       <span class="a-size-base s-underline-text">684</span>
#       <a class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal" target="_blank" href="/sspa/click?ie=UTF8&amp;spc=MToyNzk5ODY1ODc2MDkxNTUzOjE2NzU0MjQzNzU6c3BfYXRmOjIwMTA0MTQwMjYzNjk4OjowOjo&amp;url=%2FUrban-Tribe-Laptop-Backpack-Havana%2Fdp%2FB01LXNNFDF%2Fref%3Dsr_1_1_sspa%3Fcrid%3D2M096C61O4MLT%26keywords%3Dbags%26qid%3D1675424375%26sprefix%3Dba%252Caps%252C283%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1"><span class="a-size-medium a-color-base a-text-normal">URBAN TRIBE Havana 15.6" inch Laptop Backpack for Men and Women | 27L Office/Work/Casual Bag | Water Repellent | Black</span> </a>

# %%
from bs4 import BeautifulSoup
import requests
website='https://www.amazon.in/s?k=bags&page=3&crid=2M096C61O4MLT&qid=1675442339&sprefix=ba%2Caps%2C283&ref=sr_pg_3'

r=requests.get(website,headers={"User-Agent": "YZ"})
soup=BeautifulSoup(r.content,'html.parser')

# %%
soup

# %%
liiiii=soup.find("a",attrs={"class":"s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"})
print(liiiii.get('href'))
for i in soup.find('a', href = True):
  if("www.geeksforgeeks.org" in i['href']):
    nextpage = requests.get(i['href'])    
    nextsoup = BeautifulSoup(nextpage.content, 'html.parser')
    print("next url title : ",nextsoup.find('title').string)
# Out:
# /s?k=bags&page=4&crid=2M096C61O4MLT&qid=1675443041&sprefix=ba%2Caps%2C283&ref=sr_pg_3

# %%
  product_url=[]
  product_name=[]
  price=[]
  rating=[]
  number_of_reviews=[]

# %%
 def ansde(link):
  print(link)
  r=requests.get(link,headers={"User-Agent": "YZ"})
  soup=BeautifulSoup(r.content,'html.parser')
  div_data=soup.find_all("div",attrs={"class":"sg-col sg-col-4-of-12 sg-col-8-of-16 sg-col-12-of-20 s-list-col-right"})
  link=soup.find("a",attrs={"class":"s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"})
  if(link==None):
    return
  l="https://www.amazon.in"+link.get('href')
  
  for i in div_data:
    try:
      product_url.append("https://www.amazon.in/"+i.find('a',attrs={'class':"a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"}).get('href'))
    except:
      product_url.append(None)
    try:
      product_name.append(i.find('span',attrs={'class':"a-size-medium a-color-base a-text-normal"}).get_text())
    except:
      product_name.append(None)
    try:
      price.append(i.find('span',attrs={'class':"a-offscreen"}).get_text())
    except:
      price.append(None)
    try:
      rating.append(i.find('span',attrs={'class':"a-size-base"}).get_text())
    except:
      rating.append(None)
    try:
      number_of_reviews.append(i.find('span',attrs={'class':"a-size-base s-underline-text"}).get_text())
    except:
      number_of_reviews.append(None)

  return ansde(l)

# %%
ansde("https://www.amazon.in/s?k=bags&crid=2M096C61O4MLT&qid=1675443218&sprefix=ba%2Caps%2C283&ref=sr_pg_1")
# Out:
# https://www.amazon.in/s?k=bags&crid=2M096C61O4MLT&qid=1675443218&sprefix=ba%2Caps%2C283&ref=sr_pg_1
# https://www.amazon.in/s?k=bags&page=2&crid=2M096C61O4MLT&qid=1675444872&sprefix=ba%2Caps%2C283&ref=sr_pg_1
# https://www.amazon.in/s?k=bags&page=3&crid=2M096C61O4MLT&qid=1675444873&sprefix=ba%2Caps%2C283&ref=sr_pg_2
# https://www.amazon.in/s?k=bags&page=4&crid=2M096C61O4MLT&qid=1675444875&sprefix=ba%2Caps%2C283&ref=sr_pg_3
# https://www.amazon.in/s?k=bags&page=5&crid=2M096C61O4MLT&qid=1675444876&sprefix=ba%2Caps%2C283&ref=sr_pg_4
# https://www.amazon.in/s?k=bags&page=6&crid=2M096C61O4MLT&qid=1675444877&sprefix=ba%2Caps%2C283&ref=sr_pg_5
# https://www.amazon.in/s?k=bags&page=7&crid=2M096C61O4MLT&qid=1675444879&sprefix=ba%2Caps%2C283&ref=sr_pg_6
# https://www.amazon.in/s?k=bags&page=8&crid=2M096C61O4MLT&qid=1675444880&sprefix=ba%2Caps%2C283&ref=sr_pg_7
# https://www.amazon.in/s?k=bags&page=9&crid=2M096C61O4MLT&qid=1675444881&sprefix=ba%2Caps%2C283&ref=sr_pg_8
# https://www.amazon.in/s?k=bags&page=10&crid=2M096C61O4MLT&qid=1675444883&sprefix=ba%2Caps%2C283&ref=sr_pg_9
# https://www.amazon.in/s?k=bags&page=11&crid=2M096C61O4MLT&qid=1675444884&sprefix=ba%2Caps%2C283&ref=sr_pg_10
# https://www.amazon.in/s?k=bags&page=12&crid=2M096C61O4MLT&qid=1675444885&sprefix=ba%2Caps%2C283&ref=sr_pg_11
# https://www.amazon.in/s?k=bags&page=13&crid=2M096C61O4MLT&qid=1675444886&sprefix=ba%2Caps%2C283&ref=sr_pg_12
# https://www.amazon.in/s?k=bags&page=14&crid=2M096C61O4MLT&qid=1675444887&sprefix=ba%2Caps%2C283&ref=sr_pg_13
# https://www.amazon.in/s?k=bags&page=15&crid=2M096C61O4MLT&qid=1675444888&sprefix=ba%2Caps%2C283&ref=sr_pg_14
# https://www.amazon.in/s?k=bags&page=16&crid=2M096C61O4MLT&qid=1675444889&sprefix=ba%2Caps%2C283&ref=sr_pg_15
# https://www.amazon.in/s?k=bags&page=17&crid=2M096C61O4MLT&qid=1675444891&sprefix=ba%2Caps%2C283&ref=sr_pg_16
# https://www.amazon.in/s?k=bags&page=18&crid=2M096C61O4MLT&qid=1675444892&sprefix=ba%2Caps%2C283&ref=sr_pg_17
# https://www.amazon.in/s?k=bags&page=19&crid=2M096C61O4MLT&qid=1675444893&sprefix=ba%2Caps%2C283&ref=sr_pg_18
# https://www.amazon.in/s?k=bags&page=20&crid=2M096C61O4MLT&qid=1675444894&sprefix=ba%2Caps%2C283&ref=sr_pg_19

# %%
mp={}
import pandas as pd
mp['product_url']=product_url
mp['product_name']=product_name
mp['price']=price
mp['rating']=rating
mp['number_of_reviews']=number_of_reviews

# %%
df
# Out:
#                                            product_url  \
# 0    https://www.amazon.in//American-Tourister-AMT-...
# 1    https://www.amazon.in//Wesley-Milestone-Waterp...
# 2    https://www.amazon.in//ADISA-Laptop-Backpack-O...
# 3    https://www.amazon.in//Skybags-Brat-Black-Casu...
# 4    https://www.amazon.in//Safari-Backpack-Resista...
# ..                                                 ...
# 311  https://www.amazon.in//Hoteon-Backpack-Anti-Th...
# 312  https://www.amazon.in//uppercase-Backpack-2300...
# 313  https://www.amazon.in//Wooum-Resistant-Materia...
# 314  https://www.amazon.in//Caprese-Yondella-Womens...
# 315  https://www.amazon.in//HP-Odyssey-Backpack-15-...
#
#                                           product_name   price  rating  \
# 0    American Tourister 32 Ltrs Black Casual Backpa...  ₹1,199  51,380
# 1    Wesley Milestone 2.0 Casual Waterproof Laptop ...    ₹565   9,233
# 2    ADISA 15.6 inch Laptop Backpack Office Bag Col...    ₹499     463
# 3            Skybags Brat Black 46 Cms Casual Backpack    ₹669   3,373
# 4    Safari Flash Casual Backpack, 26 ltr Water Res...    ₹699   2,191
# ..                                                 ...     ...     ...
# 311  Golden Wolf Laptop Bag Business Anti-theft Bac...  ₹1,946   3,188
# 312  uppercase Medium 17 Ltrs Vegan Leather (14.6 i...  ₹1,600     109
# 313  wooum Water Resistant Material Sling Bag/One S...    ₹474     201
# 314                          Caprese Women's Sling bag  ₹1,114   1,162
# 315  HP Odyssey Backpack for 15.6-inch Laptop (Grey...  ₹2,459   5,131
#
#     number_of_reviews
# 0              51,380
# 1               9,233
# 2                 463
# 3               3,373
# 4               2,191
# ..                ...
# 311             3,188
# 312               109
# 313               201
# 314             1,162
# 315             5,131
#
# [316 rows x 5 columns]

# %%
for i in range(len(df['price'])):
  df['price'][i]=df['price'][i][1:]

# %%
df
# Out:
#                                            product_url  \
# 0    https://www.amazon.in//American-Tourister-AMT-...
# 1    https://www.amazon.in//Wesley-Milestone-Waterp...
# 2    https://www.amazon.in//ADISA-Laptop-Backpack-O...
# 3    https://www.amazon.in//Skybags-Brat-Black-Casu...
# 4    https://www.amazon.in//Safari-Backpack-Resista...
# ..                                                 ...
# 311  https://www.amazon.in//Hoteon-Backpack-Anti-Th...
# 312  https://www.amazon.in//uppercase-Backpack-2300...
# 313  https://www.amazon.in//Wooum-Resistant-Materia...
# 314  https://www.amazon.in//Caprese-Yondella-Womens...
# 315  https://www.amazon.in//HP-Odyssey-Backpack-15-...
#
#                                           product_name  price  rating  \
# 0    American Tourister 32 Ltrs Black Casual Backpa...  1,199  51,380
# 1    Wesley Milestone 2.0 Casual Waterproof Laptop ...    565   9,233
# 2    ADISA 15.6 inch Laptop Backpack Office Bag Col...    499     463
# 3            Skybags Brat Black 46 Cms Casual Backpack    669   3,373
# 4    Safari Flash Casual Backpack, 26 ltr Water Res...    699   2,191
# ..                                                 ...    ...     ...
# 311  Golden Wolf Laptop Bag Business Anti-theft Bac...  1,946   3,188
# 312  uppercase Medium 17 Ltrs Vegan Leather (14.6 i...  1,600     109
# 313  wooum Water Resistant Material Sling Bag/One S...    474     201
# 314                          Caprese Women's Sling bag  1,114   1,162
# 315  HP Odyssey Backpack for 15.6-inch Laptop (Grey...  2,459   5,131
#
#     number_of_reviews
# 0              51,380
# 1               9,233
# 2                 463
# 3               3,373
# 4               2,191
# ..                ...
# 311             3,188
# 312               109
# 313               201
# 314             1,162
# 315             5,131
#
# [316 rows x 5 columns]

# %%
r=requests.get(product_url[0],headers={"User-Agent": "XYZ"})
soup=BeautifulSoup(r.content,'html.parser')

# %%
product_description=[]
ASIN=[]
manufacturer=[]
# def part2():
for link in product_url:
  try:
    r=requests.get(link,headers={"User-Agent": "XYZ"})
    soup=BeautifulSoup(r.content,'html.parser')
    description=soup.find('div',attrs={'id':"featurebullets_feature_div"})
    dd=soup.find('div',attrs={'class':"a-section table-padding"})
    manu=soup.find('div',attrs={'class':"a-expander-content a-expander-section-content a-section-expander-inner"})
    description=soup.find('div',attrs={'id':"featurebullets_feature_div"})
    # print(manu)
    manufac=manu.find_all('td',attrs={'class':"a-size-base prodDetAttrValue"})
    m_data=manufac[8].text
    # a-section table-padding
    asin=dd.find('td',attrs={'class':"a-size-base prodDetAttrValue"}).text
    x=description.find('ul')
    desc=""
    for li in x.find_all("li"):
      desc=desc+","+li.text
    product_description.append(desc)
    ASIN.append(asin)
    manufacturer.append(m_data)
  except:
    product_description.append(None)
    ASIN.append(None)
    manufacturer.append(None)

      # print(li.text, end=" ")

# %%
m=[]
for i in manufacturer:
  try:
    m.append("".join(i.split())[2:])
  except:
    m.append(None)

# %%
m
# Out:
# ['amsonite',
#  '',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'olyester',
#  None,
#  'labinternatioanlprivatelimited',
#  None,
#  None,
#  'aptop',
#  None,
#  'olyester',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'xercise&Fitness',
#  None,
#  '5.6Inches',
#  None,
#  None,
#  'aptopBackpack',
#  '',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'O-BPS-15-20',
#  None,
#  None,
#  None,
#  None,
#  '860',
#  None,
#  None,
#  'aptopbackpack',
#  None,
#  '',
#  None,
#  '5.6Inches',
#  None,
#  None,
#  'Backpack',
#  None,
#  None,
#  'neSize',
#  '',
#  'aterResistant',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'o',
#  None,
#  'ndia',
#  None,
#  None,
#  'ndia',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ackpack',
#  None,
#  'houlderstrap',
#  None,
#  'aptopBackpack',
#  None,
#  None,
#  None,
#  None,
#  '7.3Inches',
#  'igeonIndustries(Thailand)Co.Ltd.',
#  None,
#  None,
#  'o',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '903',
#  None,
#  None,
#  'aptopbackpack',
#  None,
#  None,
#  'o',
#  None,
#  '',
#  None,
#  None,
#  None,
#  'eatherLaptopBag16inch-LightBrown',
#  'eatherLaptopBag16inch-LightBrown',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ag',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
mp["ASIN"]=ASIN
mp["product_description"]=product_description
mp["manufacturer"]=m

# %%
manufacturer
# Out:
# ['\n                \u200eSamsonite ',
#  '\n                \u200e1 ',
#  None,
#  None,
#  None,
#  None,
#  None,
#  '\n                \u200ePolyester ',
#  None,
#  '\n                \u200eFlab internatioanl private limited ',
#  None,
#  None,
#  '\n                \u200eLaptop ',
#  None,
#  '\n                \u200ePolyester ',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '\n                \u200e1 ',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '\n                \u200eExercise & Fitness ',
#  None,
#  '\n                \u200e15.6 Inches ',
#  None,
#  None,
#  '\n                \u200eLaptop Backpack ',
#  '\n                \u200e1 ',
#  None,
#  None,
#  None,
#  None,
#  None,
#  '\n                \u200ePO-BPS-15-20 ',
#  None,
#  None,
#  None,
#  None,
#  '\n                \u200e5860 ',
#  None,
#  None,
#  '\n                \u200eLaptop backpack ',
#  None,
#  '\n                \u200e1 ',
#  None,
#  '\n                \u200e15.6 Inches ',
#  None,
#  None,
#  '\n                \u200e1 Backpack ',
#  None,
#  None,
#  '\n                \u200eOne Size ',
#  '\n                \u200e1 ',
#  '\n                \u200eWater Resistant ',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '\n                \u200eNo ',
#  None,
#  '\n                \u200eIndia ',
#  None,
#  None,
#  '\n                \u200eIndia ',
#  None,
#  None,
#  None,
#  None,
#  None,
#  '\n                \u200eBackpack ',
#  None,
#  '\n                \u200eShoulder strap ',
#  None,
#  '\n                \u200eLaptop Backpack ',
#  None,
#  None,
#  None,
#  None,
#  '\n                \u200e17.3 Inches ',
#  '\n                \u200ePigeon Industries (Thailand) Co. Ltd. ',
#  None,
#  None,
#  '\n                \u200eNo ',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '\n                \u200e1903 ',
#  None,
#  None,
#  '\n                \u200eLaptop backpack ',
#  None,
#  None,
#  '\n                \u200eNo ',
#  None,
#  '\n                \u200e1 ',
#  None,
#  None,
#  None,
#  '\n                \u200eLeather Laptop Bag 16 inch - Light Brown ',
#  '\n                \u200eLeather Laptop Bag 16 inch - Light Brown ',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '\n                \u200eBag ',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '\n                \u200e1 ',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
df=pd.DataFrame(mp)

# %%
df.to_csv("results.csv")

# %%
df
# Out:
#                                            product_url  \
# 0    https://www.amazon.in//American-Tourister-AMT-...
# 1    https://www.amazon.in//Wesley-Milestone-Waterp...
# 2    https://www.amazon.in//ADISA-Laptop-Backpack-O...
# 3    https://www.amazon.in//Skybags-Brat-Black-Casu...
# 4    https://www.amazon.in//Safari-Backpack-Resista...
# ..                                                 ...
# 311  https://www.amazon.in//Hoteon-Backpack-Anti-Th...
# 312  https://www.amazon.in//uppercase-Backpack-2300...
# 313  https://www.amazon.in//Wooum-Resistant-Materia...
# 314  https://www.amazon.in//Caprese-Yondella-Womens...
# 315  https://www.amazon.in//HP-Odyssey-Backpack-15-...
#
#                                           product_name   price  rating  \
# 0    American Tourister 32 Ltrs Black Casual Backpa...  ₹1,199  51,380
# 1    Wesley Milestone 2.0 Casual Waterproof Laptop ...    ₹565   9,233
# 2    ADISA 15.6 inch Laptop Backpack Office Bag Col...    ₹499     463
# 3            Skybags Brat Black 46 Cms Casual Backpack    ₹669   3,373
# 4    Safari Flash Casual Backpack, 26 ltr Water Res...    ₹699   2,191
# ..                                                 ...     ...     ...
# 311  Golden Wolf Laptop Bag Business Anti-theft Bac...  ₹1,946   3,188
# 312  uppercase Medium 17 Ltrs Vegan Leather (14.6 i...  ₹1,600     109
# 313  wooum Water Resistant Material Sling Bag/One S...    ₹474     201
# 314                          Caprese Women's Sling bag  ₹1,114   1,162
# 315  HP Odyssey Backpack for 15.6-inch Laptop (Grey...  ₹2,459   5,131
#
#     number_of_reviews          ASIN  \
# 0              51,380   B07CJCGM1M
# 1               9,233   B084JGJ8PF
# 2                 463          None
# 3               3,373          None
# 4               2,191          None
# ..                ...           ...
# 311             3,188          None
# 312               109          None
# 313               201          None
# 314             1,162          None
# 315             5,131          None
#
#                                    product_description manufacturer
# 0    , Laptop Compatibility: No, Strap Type: Adjust...     amsonite
# 1    , 30L Capacity: The Backpack has a padded lapt...
# 2                                                 None         None
# 3                                                 None         None
# 4                                                 None         None
# ..                                                 ...          ...
# 311                                               None         None
# 312                                               None         None
# 313                                               None         None
# 314                                               None         None
# 315                                               None         None
#
# [316 rows x 8 columns]
